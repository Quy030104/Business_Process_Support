# %%
import pandas as pd

# Load data
data = pd.read_csv('asm2_data.csv')
data
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 367       334  12/28/23        NaN    ST14               3.0        2.99
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address        City
# 0      123 Main Street         NYC
# ...

# %%
df= pd.DataFrame(data)
df
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 367       334  12/28/23        NaN    ST14               3.0        2.99
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address        City
# 0      123 Main Street         NYC
# ...

# %%
df_unique = df.drop_duplicates()
df_unique
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 361       333  12/27/23      128.0    ST13               1.0       11.95
# 362       334  12/28/23        NaN    ST14               3.0        2.99
# 363       335  12/29/23      127.0    ST15               1.0       11.99
# 364       336  12/30/23      128.0    ST01               1.0        2.99
# 365       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address        City
# 0      123 Main Street         NYC
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 367       334  12/28/23        NaN    ST14               3.0        2.99
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address        City
# 0      123 Main Street         NYC
# ...

# %%
df = pd.DataFrame(data)
df
df_cleaned = df.dropna()
df_cleaned
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 365       337  12/31/23      128.0    ST02               2.0        2.99
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address        City
# 0      123 Main Street         NYC
# ...

# %%
data['City']
data.replace('NYC','New York City', inplace = True)
data
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 367       334  12/28/23        NaN    ST14               3.0        2.99
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address           City
# 0      123 Main Street  New York City
# ...

# %%
data.dropna(inplace=True)
data
# Out:
#      ResultID      Date  ProductID StoreID  Quantity Ordered  Price Each  \
# 0           1  01/01/23      101.0    ST01               1.0      700.00
# 1           2  01/02/23      102.0    ST02               1.0       14.95
# 2           3  01/03/23      103.0    ST03               2.0       11.99
# 3           4  01/04/23      104.0    ST04               1.0      149.99
# 4           5  01/05/23      105.0    ST05               1.0       11.99
# ..        ...       ...        ...     ...               ...         ...
# 365       337  12/31/23      128.0    ST02               2.0        2.99
# 366       333  12/27/23      128.0    ST13               1.0       11.95
# 368       335  12/29/23      127.0    ST15               1.0       11.99
# 369       336  12/30/23      128.0    ST01               1.0        2.99
# 370       337  12/31/23      128.0    ST02               2.0        2.99
#
#                Address           City
# 0      123 Main Street  New York City
# ...

# %%
# Phan tich du lieu
quantities = data["Quantity Ordered"]
quantities.sum()
quantities.mean()

prices = data["Price Each"]
prices.mean()
prices.median()

# Them moi cot du lieu
data["Detail Address"]= data['City']+''+data['Address']
data
data["Sale"] = data["Price Each"] * data["Quantity Ordered"]
data.describe()
# Out:
#          ResultID   ProductID  Quantity Ordered   Price Each         Sale
# count  327.000000  327.000000        327.000000   327.000000   327.000000
# mean   174.446483  120.721713          1.119266   154.289358   154.885076
# std     95.873044   12.263677          0.430254   255.259423   254.926290
# min      1.000000  101.000000          1.000000     2.990000     2.990000
# 25%     95.500000  109.000000          1.000000    11.950000    11.950000
# 50%    175.000000  123.000000          1.000000    14.950000    14.950000
# 75%    249.500000  128.000000          1.000000   150.000000   150.000000
# max    337.000000  150.000000          5.000000  1700.000000  1700.000000

# %%
import matplotlib.pyplot as plt

# Thêm cột 'Month' vào DataFrame data
data["Month"] = data["Date"].str[0:2]

# Tính tổng doanh số theo tháng
sales = data.groupby("Month").sum()["Sale"]

# Vẽ biểu đồ
plt.figure(figsize=(10, 6))
sales.plot(kind='bar', color='pink')
plt.title('Total Sales by Month')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)

# Tìm tháng có doanh số cao nhất
best_month = sales.idxmax()
best_month_sales = sales.max()
print(f'The best month for sales is {best_month} with total sales of ${best_month_sales}.')

# Hiển thị biểu đồ
plt.show()
# Out:
# The best month for sales is 09 with total sales of $10450.17.

# %%
df =pd.DataFrame(data)
city_sales = data.groupby('City').sum()['Sale']
plt.figure(figsize=(10, 6))
city_sales.plot(kind='bar', color='pink')
plt.title('Total Sales by City')
plt.xlabel('City')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)
best_city = city_sales.idxmax()
best_city_sales=city_sales.max()
print(f'The best city with the highest sales {best_city} with total sales of ${best_city_sales}.')
plt.show()
# Out:
# The best city with the highest sales Columbus with total sales of $6996.06.

# %%
N = 10
store_sales=df.groupby('StoreID')['Sale'].sum()
top_nstores=store_sales.nlargest(N)
bottom_nstores = store_sales.nsmallest(N)
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
top_nstores.plot(kind='bar',color='pink')
plt.title(f'Top {N} StoreID by Sales')
plt.xlabel('StoreID')
plt.ylabel('Total Sales')
# Out:
# Text(0, 0.5, 'Total Sales')

# %%
plt.subplot(1,2,2)
bottom_nstores.plot(kind='bar', color='pink')
plt.title(f'Bottom {N} StoreIDs by Sales')
plt.xlabel('StoresID')
plt.ylabel('Total Sales')
plt.tight_layout()
plt.show()
